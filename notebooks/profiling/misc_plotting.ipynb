# %%
import numpy as np
np.random.seed(42)
import sys
import cProfile
import humanize
sys.path.insert(0, '../..')
# %reload_ext memory_profiler
# %reload_ext autoreload
# %autoreload 1
# %aimport allel.model
# %aimport allel.stats
# %aimport allel.plot
# %matplotlib inline

# %%
pos = np.unique(np.random.randint(0, 100000, size=1000))

# %%
allel.plot.variant_locator(pos);

# %%
allel.plot.variant_locator(pos, flip=True);
